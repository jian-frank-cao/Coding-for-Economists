# %% [markdown]
# # Coding for Economists - Advanced Session 4

# %% [markdown]
# ## 1. Setup Environment

# %%
# %pip install line-profiler memory-profiler dask 'dask[distributed]'

# %%
# Install in Google Colab
# !pip install gensim bertopic

# %%
import numpy as np
import pandas as pd
# Turn on copy on write
pd.options.mode.copy_on_write = True

# %%
# Load profilers
# %load_ext line_profiler
# %load_ext memory_profiler

# %% [markdown]
# ## 2. A Slow Application

# %%
df = pd.read_csv('econ_panel.csv')
df = df[df['Indicator'] == 'NGDP_R']
df = df.drop(columns=['Indicator']).rename(columns={'Country':'code', 'Year':'year', 'Value':'value'})
df.head()
# Out:
#   code  year    value
# 0  AFG  2002   183.26
# 1  AFG  2003  198.736
# 2  AFG  2004  200.069
# 3  AFG  2005  223.737
# 4  AFG  2006  235.731

# %%
gdp['year']  = pd.to_datetime(gdp['year'], format='%Y')
gdp['value'] = pd.to_numeric(gdp['value'], errors='coerce')
# this will convert any remaining object-columns to their inferred dtypes
gdp = gdp.infer_objects()
def interpolate_country(group):
    # pick only the two columns we care about
    s = (
        group[['year', 'value']]
         .set_index('year')['value']      # annual values, DatetimeIndex
         .resample('W')                    # up-sample to weekly
         .interpolate(method='linear')     # linear fill
    )
    return s
gdp_weekly = (
    gdp
    .groupby('code', group_keys=True)
    .apply(interpolate_country)            # returns a Series named 'value'
    .reset_index()                          # brings back 'code' & 'year' as cols
)
gdp_daily.to_csv('gdp_panel.csv', index=False)

# regions = pd.read_csv('country_region.csv')
# regions.head()
# regions = regions.rename(columns={'Entity': 'country', 'Code':'code','World regions according to OWID':'region'})
# regions[['country', 'code','region']].to_csv('country_region.csv', index=False)

# %%
# Out:
# /var/folders/j4/72zz472s4sdd1r1ssyml8k5w0000gn/T/ipykernel_30612/2505499558.py:17: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(interpolate_country)            # returns a Series named 'value'

# %% [markdown]
# ### 2.1 Load Data

# %%
import csv

gdp = {}
path = 'gdp_panel.csv'
with open(path) as f:
    reader = csv.DictReader(f)
    for row in reader:
        country = row['code']
        value = float(row['value'])
        if country not in gdp:
            gdp[country] = []
        gdp[country].append(value)

mapping = {}
path = 'country_region.csv'
with open(path) as f:
    reader = csv.DictReader(f)
    for row in reader:
        country = row['code']
        region = row['region']
        if country not in mapping:
            mapping[country] = region

print(gdp['IRL'])
# Out:
# [50.393, 50.39645901639344, 50.399918032786886, 50.40337704918033, 50.40683606557377, 50.41029508196721, 50.413754098360656, 50.4172131147541, 50.42067213114754, 50.42413114754098, 50.427590163934426, 50.43104918032787, 50.43450819672131, 50.43796721311475, 50.441426229508195, 50.44488524590164, 50.44834426229508, 50.45180327868852, 50.455262295081965, 50.45872131147541, 50.46218032786885, 50.46563934426229, 50.469098360655735, 50.47255737704918, 50.47601639344262, 50.47947540983606, 50.482934426229505, 50.486393442622955, 50.4898524590164, 50.49331147540984, 50.49677049180328, 50.500229508196725, 50.50368852459017, 50.50714754098361, 50.51060655737705, 50.514065573770495, 50.51752459016394, 50.52098360655738, 50.52444262295082, 50.527901639344265, 50.53136065573771, 50.53481967213115, 50.53827868852459, 50.541737704918035, 50.54519672131148, 50.54865573770492, 50.55211475409836, 50.555573770491804, 50.55903278688525, 50.56249180327869, 50.56595081967213, 50.569409836065574, 50.57286885245902, 50.57632786885246, 50.5797868852459, 50.583245901639344, 50.58670491803279, 50.59016393442623, 50.59362295081967, 50.597081967213114, 50.60054098360656, 50.604, 50.60745901639344, 50.610918032786884, 50.61437704918033, 50.61783606557377, 50.62129508196721, 50.624754098360654, 50.6282131147541, 50.63167213114754, 50.63513114754098, 50.638590163934424, 50.64204918032787, 50.64550819672131, 50.64896721311475, 50.652426229508194, 50.655885245901636, 50.65934426229508, 50.66280327868852, 50.66626229508197, 50.66972131147541, 50.673180327868856, 50.6766393442623, 50.68009836065574, 50.68355737704918, 50.687016393442626, 50.69047540983607, 50.69393442622951, 50.69739344262295, 50.700852459016396, 50.70431147540984, 50.70777049180328, 50.71122950819672, 50.714688524590166, 50.71814754098361, 50.72160655737705, 50.72506557377049, 50.728524590163936, 50.73198360655738, 50.73544262295082, 50.73890163934426, 50.742360655737706, 50.74581967213115, 50.74927868852459, 50.75273770491803, 50.756196721311476, 50.75965573770492, 50.76311475409836, 50.7665737704918, 50.770032786885245, 50.77349180327869, 50.77695081967213, 50.78040983606557, 50.783868852459015, 50.78732786885246, 50.7907868852459, 50.79424590163934, 50.797704918032785, 50.80116393442623, 50.80462295081967, 50.80808196721311, 50.811540983606555, 50.815, 50.81845901639344, 50.82191803278688, 50.825377049180325, 50.82883606557377, 50.83229508196721, 50.83575409836065, 50.839213114754095, 50.84267213114754, 50.84613114754099, 50.84959016393443, 50.85304918032787, 50.856508196721315, 50.85996721311476, 50.8634262295082, 50.86688524590164, 50.870344262295085, 50.87380327868853, 50.87726229508197, 50.88072131147541, 50.884180327868854, 50.8876393442623, 50.89109836065574, 50.89455737704918, 50.898016393442624, 50.90147540983607, 50.90493442622951, 50.90839344262295, 50.911852459016394, 50.91531147540984, 50.91877049180328, 50.92222950819672, 50.925688524590164, 50.92914754098361, 50.93260655737705, 50.93606557377049, 50.939524590163934, 50.94298360655738, 50.94644262295082, 50.94990163934426, 50.953360655737704, 50.95681967213115, 50.96027868852459, 50.96373770491803, 50.967196721311474, 50.97065573770492, 50.97411475409836, 50.9775737704918, 50.981032786885244, 50.98449180327869, 50.98795081967213, 50.99140983606557, 50.994868852459014, 50.998327868852456, 51.0017868852459, 51.00524590163934, 51.008704918032784, 51.012163934426226, 51.01562295081967, 51.01908196721311, 51.022540983606554, 51.025999999999996, 51.029459016393446, 51.03291803278689, 51.03637704918033, 51.03983606557377, 51.043295081967216, 51.04675409836066, 51.0502131147541, 51.05367213114754, 51.057131147540986, 51.06059016393443, 51.06404918032787, 51.06750819672131, 51.070967213114756, 51.0744262295082, 51.07788524590164, 51.08134426229508, 51.084803278688526, 51.08826229508197, 51.09172131147541, 51.09518032786885, 51.098639344262295, 51.10209836065574, 51.10555737704918, 51.10901639344262, 51.112475409836065, 51.11593442622951 ...

# %%
print(mapping['IRL'])
# Out:
# Europe

# %% [markdown]
# ### 2.2 Compute GDP Growth and Volatility

# %%
from statistics import pstdev

metrics = {}
window = 365
for country, series in gdp.items():
    growth = []
    vol = []
    for i in range(window, len(series)):
        prev = series[i-window]
        curr = series[i]
        growth.append((curr - prev) / prev)
        vol.append(pstdev(series[i-window:i]))
    metrics[country] = {'growth': growth, 'vol': vol}

print(metrics['IRL'])
# Out:
# {'growth': [0.025053896049184524, 0.02505217644747351, 0.025023791405490287, 0.02499541025944927, 0.024967033008548703, 0.024938659651986477, 0.024910290188961275, 0.024881924618671433, 0.024853562940316074, 0.024825205153093968, 0.02479685125620468, 0.024768501248847424, 0.0247401551302222, 0.024711812899528663, 0.02468347455596725, 0.02465514009873805, 0.02462680952704195, 0.02459848284007948, 0.02457016003705195, 0.024541841117160332, 0.024513526079606378, 0.024485214923591504, 0.024456907648317892, 0.024428604252987395, 0.024400304736802634, 0.0243720090989659, 0.024343717338680255, 0.024315429455148276, 0.024287145447573755, 0.024258865315159705, 0.02423058905711006, 0.024202316672628423, 0.02417404816091916, 0.024145783521186306, 0.024117522752634676, 0.024089265854468866, 0.02406101282589371, 0.02403276366611467, 0.024004518374336863, 0.02397627694976619, 0.02394803939160821, 0.02391980569906925, 0.023891575871355302, 0.023863349907673134, 0.023835127807229177, 0.023806909569230626, 0.023778695192884343, 0.023750484677397963, 0.023722278021978783, 0.023694075225834867, 0.02366587628817395, 0.023637681208204527, 0.023609489985134763, 0.02358130261817359, 0.02355311910652961, 0.023524939449412186, 0.023496763646030344, 0.02346859169559389, 0.023440423597312278, 0.02341225935039574, 0.02338409895405418, 0.023355942407498248, 0.023327789709938273, 0.023299640860585353, 0.023271495858650244, 0.023243354703344474, 0.023215217393879228, 0.023187083929466463, 0.023158954309317942, 0.023130828532645628, 0.023102706598662134, 0.02307458850657972, 0.023046474255611425, 0.023018363844969938, 0.022990257273868726, 0.02296215454152091, 0.022934055647140395, 0.02290596058994072, 0.022877869369136224, 0.022849781983940734, 0.0228216984335693, 0.022793618717236185, 0.022765542834156573, 0.022737470783545304, 0.02270940256461799, 0.0226813381765899, 0.022653277618677074, 0.022625220890095207, 0.02259716799006077, 0.022569118917789885, 0.022541073672499447, 0.02251303225340601, 0.0224849946597269, 0.02245696089067909, 0.022428930945480336, 0.022400904823348042, 0.022372882523500386, 0.022344864045155198, 0.022316849387531083, 0.022288838549846306, 0.02226083153131989, 0.022232828331170663, 0.022204828948617663, 0.02217683338288056, 0.022148841633178675, 0.022120853698732103, 0.022092869578760596, 0.022064889272484674, 0.02203691277912451, 0.02200894009790105, 0.02198097122803489, 0.021953006168747402, 0.021925044919259614, 0.021897087478793313, 0.02186913384656995, 0.021841184021811743, 0.021813238003740566, 0.021785295791579055, 0.021757357384549512, 0.021729422781875, 0.02170149198277824, 0.021673564986482718, 0.021645641792211578, 0.02161772239918873, 0.02158980680663774, 0.021561895013782938, 0.02153398701984832, 0.021506082824058637, 0.021478182425638297, 0.021450285823812483, 0.021422393017806025, 0.02139450400684438, 0.02136661879015309, 0.02133873736695803, 0.021310859736485013, 0.02128298589796007, 0.02125511585060985, 0.02122724959366066, 0.021199387126339574, 0.021171528447873324, 0.021143673557489397, 0.021115822454414943, 0.02108797513787788, 0.02106013160710577, 0.021032291861326956, 0.021004455899769417, 0.020976623721661914, 0.020948795326232846, 0.020920970712711397, 0.020893149880326384, 0.020865332828307406, 0.020837519555883702, 0.02080971006228529, 0.02078190434674183, 0.020754102408483754, 0.020726304246741142, 0.020698509860744844, 0.02067071924972536, 0.020642932412913956, 0.020615149349541548, 0.020587370058839823, 0.020559594540040117, 0.02053182279237453, 0.02050405481507481, 0.020476290607373483, 0.020448530168502715, 0.02042077349769544, 0.020393020594184248, 0.02036527145720249, 0.020337526085983302, 0.020309784479760038, 0.020282046637766678, 0.020254312559236844, 0.02022658224340493, 0.02019885568950498, 0.020171132896771797, 0.020143413864439838, 0.020115698591744332, 0.020087987077920148, 0.02006027932220292, 0.020032575323827944, 0.020004875082031266, 0.019977178596048587, 0.01994948586511638, 0.01992179 ...

# %% [markdown]
# ### 2.3 Aggregate Regions

# %%
# mapping: country → region
agg = {}  # plain dict

# Collect all growth & vol values by region
for country, m in metrics.items():
    region = mapping[country]
    if region not in agg:
        agg[region] = {'growth': [], 'vol': []}
    agg[region]['growth'].extend(m['growth'])
    agg[region]['vol'].extend(m['vol'])

# Compute regional averages
result = {}
for region, d in agg.items():
    total_growth = sum(d['growth'])
    total_vol    = sum(d['vol'])
    count_growth = len(d['growth'])
    count_vol    = len(d['vol'])
    result[region] = {
        'avg_growth': total_growth / count_growth if count_growth else 0,
        'avg_vol':    total_vol    / count_vol    if count_vol    else 0
    }

print(result)
# Out:
# {'Asia': {'avg_growth': 0.051404015722441514, 'avg_vol': 3481.3651531567803}, 'Africa': {'avg_growth': 0.04026273762645489, 'avg_vol': 53.30404019347396}, 'Europe': {'avg_growth': 0.022876323584881706, 'avg_vol': 46.059394111544194}, 'South America': {'avg_growth': 0.028355296970392158, 'avg_vol': 407.22675804007355}, 'North America': {'avg_growth': 0.029643883289800194, 'avg_vol': 11.192510511272188}, 'Oceania': {'avg_growth': 0.024703008920248598, 'avg_vol': 1.043666657089604}}

# %% [markdown]
# ### 2.4 Time and Memory Profiling

# %%
def run_analysis_v0():
    # Load Data
    gdp = {}
    path = 'gdp_panel.csv'
    with open(path) as f:
        reader = csv.DictReader(f)
        for row in reader:
            country = row['code']
            value = float(row['value'])
            if country not in gdp:
                gdp[country] = []
            gdp[country].append(value)
    
    mapping = {}
    path = 'country_region.csv'
    with open(path) as f:
        reader = csv.DictReader(f)
        for row in reader:
            country = row['code']
            region = row['region']
            if country not in mapping:
                mapping[country] = region

    # Compute dgp growth rate and volitility
    metrics = {}
    window = 365
    for country, series in gdp.items():
        growth = []
        vol = []
        for i in range(window, len(series)):
            prev = series[i-window]
            curr = series[i]
            growth.append((curr - prev) / prev)
            vol.append(pstdev(series[i-window:i]))
        metrics[country] = {'growth': growth, 'vol': vol}

    # Aggregate Regions
    agg = {}  # plain dict

    for country, m in metrics.items():
        region = mapping[country]
        if region not in agg:
            agg[region] = {'growth': [], 'vol': []}
        agg[region]['growth'].extend(m['growth'])
        agg[region]['vol'].extend(m['vol'])
    
    result = {}
    for region, d in agg.items():
        total_growth = sum(d['growth'])
        total_vol    = sum(d['vol'])
        count_growth = len(d['growth'])
        count_vol    = len(d['vol'])
        result[region] = {
            'avg_growth': total_growth / count_growth if count_growth else 0,
            'avg_vol':    total_vol    / count_vol    if count_vol    else 0
        }
    return result
    
# %lprun -f run_analysis_v0 run_analysis_v0()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 512.162 s
# File: /var/folders/j4/72zz472s4sdd1r1ssyml8k5w0000gn/T/ipykernel_30612/1188526080.py
# Function: run_analysis_v0 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run_analysis_v0():
#      2                                               # Load Data
#      3         1       9000.0   9000.0      0.0      gdp = {}
#      4         1          0.0      0.0      0.0      path = 'gdp_panel.csv'
#      5         2     481000.0 240500.0      0.0      with open(path) as f:
#      6         1     109000.0 109000.0      0.0          reader = csv.DictReader(f)
#      7   2518945 2995416000.0   1189.2      0.6          for row in reader:
#      8   2518944  150304000.0     59.7      0.0              country = row['code']
#      9   2518944  473084000.0    187.8      0.1              value = float(row['value'])
#     10   2518944  172232000.0     68.4      0.0              if country not in gdp:
#     11       189      41000.0    216.9      0.0                  gdp[country] = []
#     12   2518944  176106000.0     69.9      0.0              gdp[country].append(value)
#     13
#     14         1          0.0      0.0      0.0      mapping = {}
#     15         1       1000.0   1000.0      0.0      path = 'country_region.csv'
#     16         2      89000.0  44500.0      0.0      with open(path) as f:
#     17         1       8000.0   8000.0      0.0          reader = csv.DictReader(f)
#     18       272    1042000.0   3830.9      0.0          for row in reader:
#     19       271      14000.0     51.7      0.0              country = row['code']
#     20       271      21000.0     77.5      0.0              region = row['region']
#     21       271      22000.0     81.2      0.0              if country not in mapping:
#     22       258      33000.0    127.9      0.0                  mapping[country] = region
#     23
#     24                                               # Compute dgp growth rate and volitility
#     25         1          0.0      0.0      0.0      metrics = {}
#     26         1          0.0      0.0      0.0      window = 365
#     27       190      74000.0    389.5      0.0      for country, series in gdp.items():
#     28       189      27000.0    142.9      0.0          growth = []
#     29       189      21000.0    111.1      0.0          vol = []
#     30   2450148  204932000.0     83.6      0.0          for i in range(window, len(series)):
#     31   2449959  184254000.0     75.2      0.0              prev = series[i-window]
#     32   2449959  149323000.0     60.9      0.0              curr = series[i]
#     33   2449959  204736000.0     83.6      0.0              growth.append((curr - prev) / prev)
#     34   2449959        5e+11 207110.6     99.1              vol.append(pstdev(series[i-window:i]))
#     35       189     166000.0    878.3      0.0          metrics[country] = {'growth': growth, 'vol': vol}
#     36
#     37                                               # Aggregate Regions
#     38         1          0.0      0.0      0.0      agg = {}  # plain dict
#     39
#     40       190      32000.0    168.4      0.0      for country, m in metrics.items():
#     41       189      47000.0    248.7      0.0          region = mapping[country]
#     42       189      24000.0    127.0      0.0          if region not in agg:
#     43         6       1000.0    166.7      0.0              agg[region] = {'growth': [], 'vol': []}
#     44       189   13347000.0  70619.0      0.0          agg[region]['growth'].extend(m['growth'])
#     45       189    9644000.0  51026.5      0.0          agg[region]['vol'].extend(m['vol'])
#     46
#     47         1          0.0      0.0      0.0      result = {}
#     48         7       4000.0    571.4      0.0      for region, d in agg.items():
#     49         6    6794000.0    1e+06      0.0          total_growth = sum(d['growth'])
#     50         6    6708000.0    1e+06      0.0          total_vol    = sum(d['vol'])
#     51         6       5000.0    833.3      0.0          count_growth = len(d['growth'])
#     52         6          0.0      0.0      0.0          count_vol    = len(d['vol'])
#     53         6       5000.0    833.3      0.0          result[region] = {
#     54         6       3000.0    500.0      0.0              'avg_growth': total_growth / count_growth if count_growth else 0,
#     55         6       1000.0    166.7      0.0              'avg_vol':    total_vol    / count_vol    if count_vol    else 0
#     56                                                   }
#     57         1       2000.0   2000.0      0.0      return result

# %%
import sys
!"{sys.executable}" -m memory_profiler app_v0.py
# Out:
# ^C
# Filename: app_v0.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     10   54.688 MiB   54.688 MiB           1   @profile
#     11                                         def run_analysis_v0():
#     12                                             # Load Data
#     13   54.688 MiB    0.000 MiB           1       gdp = {}
#     14   54.688 MiB    0.000 MiB           1       path = 'gdp_panel.csv'
#     15  153.844 MiB    0.000 MiB           2       with open(path) as f:
#     16   54.688 MiB    0.000 MiB           1           reader = csv.DictReader(f)
#     17  153.844 MiB    0.156 MiB     2518945           for row in reader:
#     18  153.844 MiB    0.000 MiB     2518944               country = row['code']
#     19  153.844 MiB    0.000 MiB     2518944               value = float(row['value'])
#     20  153.844 MiB   77.156 MiB     2518944               if country not in gdp:
#     21  153.562 MiB    0.000 MiB         189                   gdp[country] = []
#     22  153.844 MiB   21.844 MiB     2518944               gdp[country].append(value)
#     23
#     24  153.844 MiB    0.000 MiB           1       mapping = {}
#     25  153.844 MiB    0.000 MiB           1       path = 'country_region.csv'
#     26  153.891 MiB    0.016 MiB           2       with open(path) as f:
#     27  153.859 MiB    0.000 MiB           1           reader = csv.DictReader(f)
#     28  153.891 MiB    0.031 MiB         272           for row in reader:
#     29  153.891 MiB    0.000 MiB         271               country = row['code']
#     30  153.891 MiB    0.000 MiB         271               region = row['region']
#     31  153.891 MiB    0.000 MiB         271               if country not in mapping:
#     32  153.891 MiB    0.000 MiB         258                   mapping[country] = region
#     33
#     34                                             # Compute dgp growth rate and volitility
#     35  153.891 MiB    0.000 MiB           1       metrics = {}
#     36  153.891 MiB    0.000 MiB           1       window = 365
#     37  177.906 MiB -923.922 MiB          76       for country, series in gdp.items():
#     38  177.906 MiB -923.906 MiB          76           growth = []
#     39  177.906 MiB -923.891 MiB          76           vol = []
#     40  177.969 MiB -13083852.469 MiB     1016573           for i in range(window, len(series)):
#     41  177.969 MiB -13082929.609 MiB     1016498               prev = series[i-window]
#     42  177.969 MiB -13082930.453 MiB     1016498               curr = series[i]
#     43  177.969 MiB -13082923.000 MiB     1016498               growth.append((curr - prev) / prev)
#     44  177.969 MiB -13082905.672 MiB     1016497               vol.append(pstdev(series[i-window:i]))
#     45  177.906 MiB -938.500 MiB          75           metrics[country] = {'growth': growth, 'vol': vol}
#     46
#     47                                             # Aggregate Regions
#     48                                             agg = {}  # plain dict
#     49
#     50                                             for country, m in metrics.items():
#     51                                                 region = mapping[country]
#     52                                                 if region not in agg:
#     53                                                     agg[region] = {'growth': [], 'vol': []}
#     54                                                 agg[region]['growth'].extend(m['growth'])
#     55                                                 agg[region]['vol'].extend(m['vol'])
#     56
#     57                                             result = {}
#     58                                             for region, d in agg.items():
#     59                                                 total_growth = sum(d['growth'])
#     60                                                 total_vol    = sum(d['vol'])
#     61                                                 count_growth = len(d['growth'])
#     62                                                 count_vol    = len(d['vol'])
#     63                                                 result[region] = {
#     64                                                     'avg_growth': total_growth / count_growth if count_growth else 0,
#     65                                                     'avg_vol':    total_vol    / count_vol    if count_vol    else 0
#     66                                                 }
#     67                                             return result
#
#
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/site-packages/memory_profiler.py", line 1351, in <module>
#     exec_with_profiler(script_filename, prof, args.backend, script_args)
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/site-packages/memory_profiler.py", line 1252, in exec_with_profiler
#     exec(compile(f.read(), filename, 'exec'), ns, ns)
#   File "app_v0.py", line 70, in <module>
#     run_analysis_v0()
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/site-packages/memory_profiler.py", line 761, in f
#     return func(*args, **kwds)
#            ^^^^^^^^^^^^^^^^^^^
#   File "app_v0.py", line 44, in run_analysis_v0
#     vol.append(pstdev(series[i-window:i]))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/statistics.py", line 986, in pstdev
#     T, ss, c, n = _ss(data, mu)
#                   ^^^^^^^^^^^^^
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/statistics.py", line 228, in _ss
#     count += 1
#     ^^^^^
#   File "/opt/anaconda3/envs/pyenv02/lib/python3.12/site-packages/memory_profiler.py", line 791, in trace_memory_usage
#     def trace_memory_usage(self, frame, event, arg):
#
# KeyboardInterrupt

# %% [markdown]
# ## 3. Panda Dataframe

# %% [markdown]
# ### 3.1 Load Data

# %%
import pandas as pd
gdp = pd.read_csv(
    'gdp_panel.csv',
    usecols=['code','year','value'], # Only read necessary columns
    parse_dates=['year'],
    dtype={'code':'category'}
).sort_values(['code','year'])

gdp.head()
# Out:
#   code       year    value
# 0  AFG 2002-01-01  183.260
# 1  AFG 2003-01-01  198.736
# 2  AFG 2004-01-01  200.069
# 3  AFG 2005-01-01  223.737
# 4  AFG 2006-01-01  235.731

# %%
mapping = pd.read_csv(
    'country_region.csv',
    usecols=['code','region'], # Only read necessary columns
    dtype={'code':'category', 'region':'category'}
).sort_values(['code'])

mapping.head()
# Out:
#    code         region
# 11  ABW  North America
# 0   AFG           Asia
# 6   AGO         Africa
# 7   AIA  North America
# 1   ALA         Europe

# %% [markdown]
# ### 3.2 Compute GDP Growth and Volatility

# %%
window = 365
# pivot to wide form: rows=date, cols=country
panel = gdp.pivot(index='year', columns='code', values='value')

# rolling growth: pct_change over window periods
growth = panel.pct_change(periods=window, fill_method=None)

# rolling volatility: std over window periods
vol = panel.rolling(window=window).std()

# melt back to long form & merge region info
growth = growth.stack().rename('growth').reset_index()
vol    = vol.stack().rename('vol').reset_index()
metrics = pd.merge(growth, vol, on=['year','code'])
metrics = metrics.merge(mapping, on='code')

metrics.head()
# Out:
#         year code    growth        vol         region
# 0 1984-01-01  AGO  0.055920  15.980693         Africa
# 1 1984-01-01  ALB  0.121608   8.694685         Europe
# 2 1984-01-01  ARE -0.007765  18.792364           Asia
# 3 1984-01-01  ARG -0.034092   8.660888  South America
# 4 1984-01-01  ATG  0.192771   0.063253  North America

# %% [markdown]
# ### 3.3 Aggregate Regions

# %%
result = (
    metrics
    .groupby(['region'], observed=False)
    .agg(avg_growth=('growth','mean'),
         avg_vol=('vol','mean'))
)

print(result)
# Out:
#                avg_growth       avg_vol
# region
# Africa           0.184300    237.669407
# Asia             0.233143  15548.356671
# Europe           0.100774    196.459055
# North America    0.129856     48.756135
# Oceania          0.106929      4.802754
# South America    0.127411   1836.365379

# %% [markdown]
# ### 3.4 Time and Memory Profiling

# %%
def run_analysis_v1():
    # Load Data
    gdp = pd.read_csv(
        'gdp_panel.csv',
        usecols=['code','year','value'], # Only read necessary columns
        parse_dates=['year'],
        dtype={'code':'category'}
    ).sort_values(['code','year'])

    mapping = pd.read_csv(
        'country_region.csv',
        usecols=['code','region'], # Only read necessary columns
        dtype={'code':'category', 'region':'category'}
    ).sort_values(['code'])

    window = 365
    # Compute GDP Growth and Volatility
    # pivot to wide form: rows=date, cols=country
    panel = gdp.pivot(index='year', columns='code', values='value')
    
    # rolling growth: pct_change over window periods
    growth = panel.pct_change(periods=window, fill_method=None)
    
    # rolling volatility: std over window periods
    vol = panel.rolling(window=window).std()
    
    # melt back to long form & merge region info
    growth = growth.stack().rename('growth').reset_index()
    vol    = vol.stack().rename('vol').reset_index()
    metrics = pd.merge(growth, vol, on=['year','code'])
    metrics = metrics.merge(mapping, on='code')

    # Aggregate Regions
    result = (
        metrics
        .groupby(['region'], observed=False)
        .agg(avg_growth=('growth','mean'),
             avg_vol=('vol','mean'))
    )
    return result

# %lprun -f run_analysis_v1 run_analysis_v1()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.025206 s
# File: /var/folders/j4/72zz472s4sdd1r1ssyml8k5w0000gn/T/ipykernel_30612/2510214605.py
# Function: run_analysis_v1 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run_analysis_v1():
#      2                                               # Load Data
#      3         3   11683000.0    4e+06     46.4      gdp = pd.read_csv(
#      4         1          0.0      0.0      0.0          'gdp_panel.csv',
#      5         1          0.0      0.0      0.0          usecols=['code','year','value'], # Only read necessary columns
#      6         1       1000.0   1000.0      0.0          parse_dates=['year'],
#      7         1          0.0      0.0      0.0          dtype={'code':'category'}
#      8         1     591000.0 591000.0      2.3      ).sort_values(['code','year'])
#      9
#     10         3    1375000.0 458333.3      5.5      mapping = pd.read_csv(
#     11         1          0.0      0.0      0.0          'country_region.csv',
#     12         1          0.0      0.0      0.0          usecols=['code','region'], # Only read necessary columns
#     13         1          0.0      0.0      0.0          dtype={'code':'category', 'region':'category'}
#     14         1     234000.0 234000.0      0.9      ).sort_values(['code'])
#     15
#     16                                               # Compute GDP Growth and Volatility
#     17                                               # pivot to wide form: rows=date, cols=country
#     18         1    1361000.0    1e+06      5.4      panel = gdp.pivot(index='year', columns='code', values='value')
#     19
#     20                                               # rolling growth: pct_change over 4 periods
#     21         1     499000.0 499000.0      2.0      growth = panel.pct_change(periods=4, fill_method=None)
#     22
#     23                                               # rolling volatility: std over 4 periods
#     24         1    3702000.0    4e+06     14.7      vol = panel.rolling(window=4).std()
#     25
#     26                                               # melt back to long form & merge region info
#     27         1     814000.0 814000.0      3.2      growth = growth.stack().rename('growth').reset_index()
#     28         1     741000.0 741000.0      2.9      vol    = vol.stack().rename('vol').reset_index()
#     29         1    1272000.0    1e+06      5.0      metrics = pd.merge(growth, vol, on=['year','code'])
#     30         1    1073000.0    1e+06      4.3      metrics = metrics.merge(mapping, on='code')
#     31
#     32                                               # Aggregate Regions
#     33         1          0.0      0.0      0.0      result = (
#     34         1          0.0      0.0      0.0          metrics
#     35         1     136000.0 136000.0      0.5          .groupby(['region'], observed=False)
#     36         2    1723000.0 861500.0      6.8          .agg(avg_growth=('growth','mean'),
#     37         1          0.0      0.0      0.0               avg_vol=('vol','mean'))
#     38                                               )
#     39         1       1000.0   1000.0      0.0      return result

# %%
import sys
!"{sys.executable}" -m memory_profiler app_v1.py
# Out:
# Filename: app_v1.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#      9  120.953 MiB  120.953 MiB           1   @profile
#     10                                         def run_analysis_v1():
#     11                                             # Load Data
#     12  124.531 MiB    3.344 MiB           3       gdp = pd.read_csv(
#     13  120.953 MiB    0.000 MiB           1           'gdp_panel.csv',
#     14  120.953 MiB    0.000 MiB           1           usecols=['code','year','value'], # Only read necessary columns
#     15  120.953 MiB    0.000 MiB           1           parse_dates=['year'],
#     16  120.953 MiB    0.000 MiB           1           dtype={'code':'category'}
#     17  124.531 MiB    0.234 MiB           1       ).sort_values(['code','year'])
#     18
#     19  124.703 MiB    0.172 MiB           3       mapping = pd.read_csv(
#     20  124.531 MiB    0.000 MiB           1           'country_region.csv',
#     21  124.531 MiB    0.000 MiB           1           usecols=['code','region'], # Only read necessary columns
#     22  124.531 MiB    0.000 MiB           1           dtype={'code':'category', 'region':'category'}
#     23  124.703 MiB    0.000 MiB           1       ).sort_values(['code'])
#     24
#     25                                             # Compute GDP Growth and Volatility
#     26                                             # pivot to wide form: rows=date, cols=country
#     27  125.094 MiB    0.391 MiB           1       panel = gdp.pivot(index='year', columns='code', values='value')
#     28
#     29                                             # rolling growth: pct_change over 4 periods
#     30  125.125 MiB    0.031 MiB           1       growth = panel.pct_change(periods=4, fill_method=None)
#     31
#     32                                             # rolling volatility: std over 4 periods
#     33  125.266 MiB    0.141 MiB           1       vol = panel.rolling(window=4).std()
#     34
#     35                                             # melt back to long form & merge region info
#     36  125.297 MiB    0.031 MiB           1       growth = growth.stack().rename('growth').reset_index()
#     37  125.312 MiB    0.016 MiB           1       vol    = vol.stack().rename('vol').reset_index()
#     38  126.172 MiB    0.859 MiB           1       metrics = pd.merge(growth, vol, on=['year','code'])
#     39  126.219 MiB    0.047 MiB           1       metrics = metrics.merge(mapping, on='code')
#     40
#     41                                             # Aggregate Regions
#     42  126.438 MiB    0.000 MiB           1       result = (
#     43  126.219 MiB    0.000 MiB           1           metrics
#     44  126.219 MiB    0.000 MiB           1           .groupby(['region'], observed=False)
#     45  126.438 MiB    0.219 MiB           2           .agg(avg_growth=('growth','mean'),
#     46  126.219 MiB    0.000 MiB           1                avg_vol=('vol','mean'))
#     47                                             )
#     48  126.438 MiB    0.000 MiB           1       return result

# %% [markdown]
# ## 4. Memory Bound -> Process by Chunk

# %% [markdown]
# ### 4.1 Prepare Parquet Data

# %%
import dask.dataframe as dd

# Read the raw CSV in parallel
ddf = dd.read_csv(
    'gdp_panel.csv',
    usecols=['code','year','value'],
    parse_dates=['year'],
    dtype={'code':'category'}
)
ddf['code'] = ddf['code'].astype(str)

# Write out as partitioned Parquet
#    Here we partition by 'country' so that each country’s data lives in its own sub-folder.
ddf.to_parquet(
    'gdp_panel_parquet/',
    engine='pyarrow',
    write_index=False,         # drop the old CSV index
    partition_on=['code'],  # creates subfolders country=AAA, country=BBB, …
    compression='snappy'       # fast compression
)

# Read the raw CSV in parallel
ddf_region = dd.read_csv(
    'country_region.csv',
    usecols=['code','region'],
    dtype={'code':'category'}
)
ddf_region['code'] = ddf_region['code'].astype(str)

# Write out as partitioned Parquet
ddf_region.to_parquet(
    'country_region_parquet/',
    engine='pyarrow',
    write_index=False,         # drop the old CSV index
    partition_on=['code'],  # creates subfolders country=AAA, country=BBB, …
    compression='snappy'       # fast compression
)

# %% [markdown]
# ### 4.2 Load Data

# %%
import dask.dataframe as dd
import pandas as pd

ddf = dd.read_parquet(
    'gdp_panel_parquet/',
    columns=['code','year','value'],
    engine='pyarrow'
)

regions = dd.read_parquet('country_region_parquet/')

# %% [markdown]
# ### 4.3 Compute GDP Growth and Volatility

# %%
def summarize_country(df, window=365):
    # If this slice is empty, return an empty DataFrame
    if df.empty:
        return pd.DataFrame(columns=['code','mean_growth','mean_vol'])

    # Otherwise do the rolling stats
    df = df.sort_values('year')
    growth = df['value'].pct_change(periods=window, fill_method=None).mean()
    vol    = df['value'].rolling(window=window).std().mean()
    return pd.DataFrame({
        'code':        [df['code'].iat[0]],
        'mean_growth': [growth],
        'mean_vol':    [vol]
    })

# Build a proper meta so Dask knows what comes back
meta = pd.DataFrame({
    'code':        pd.Series(dtype='object'),
    'mean_growth': pd.Series(dtype='float64'),
    'mean_vol':    pd.Series(dtype='float64'),
})

country_summaries = ddf.groupby('code', observed=True).apply(
    summarize_country,
    meta=meta
)

country_summaries = country_summaries.reset_index(drop=True)

# %% [markdown]
# ### 4.4 Aggregate Regions

# %%
country_summaries = country_summaries.astype({'code': 'string'})
regions = regions.astype({'code': 'string'})

country_summaries = country_summaries.merge(regions, on='code')

regional_stats = (
    country_summaries
    .groupby('region', observed=True)[['mean_growth', 'mean_vol']]
    .mean()
    .compute()
)

regional_stats
# Out:
#                mean_growth      mean_vol
# region
# Africa            0.183315    220.190844
# Asia              0.238960  13674.881557
# North America     0.129856     48.059538
# Europe            0.103997    230.764849
# South America     0.127411   1800.576875
# Oceania           0.099840      4.007155

# %% [markdown]
# ### 4.5 Time and Memory Profiling

# %%
def run_analysis_v2():
    # Load data
    ddf = dd.read_parquet(
        'gdp_panel_parquet/',
        columns=['code','year','value'],
        engine='pyarrow'
    )
    
    regions = dd.read_parquet('country_region_parquet/')

    # Compute GDP Growth and Volatility
    meta = pd.DataFrame({
        'code':        pd.Series(dtype='object'),
        'mean_growth': pd.Series(dtype='float64'),
        'mean_vol':    pd.Series(dtype='float64'),
    })
    
    country_summaries = ddf.groupby('code', observed=True).apply(
        summarize_country,
        meta=meta
    )
    
    country_summaries = country_summaries.reset_index(drop=True)

    # Aggregate regions
    country_summaries = country_summaries.astype({'code': 'string'})
    regions = regions.astype({'code': 'string'})
    
    country_summaries = country_summaries.merge(regions, on='code')
    
    result = (
        country_summaries
        .groupby('region', observed=True)[['mean_growth', 'mean_vol']]
        .mean()
        .compute()
    )
    return result

# %lprun -f run_analysis_v2 run_analysis_v2()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 2.40633 s
# File: /var/folders/j4/72zz472s4sdd1r1ssyml8k5w0000gn/T/ipykernel_30612/1602383827.py
# Function: run_analysis_v2 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run_analysis_v2():
#      2                                               # Load data
#      3         2   33791000.0    2e+07      1.4      ddf = dd.read_parquet(
#      4         1          0.0      0.0      0.0          'gdp_panel_parquet/',
#      5         1          0.0      0.0      0.0          columns=['code','year','value'],
#      6         1          0.0      0.0      0.0          engine='pyarrow'
#      7                                               )
#      8
#      9         1   32015000.0    3e+07      1.3      regions = dd.read_parquet('country_region_parquet/')
#     10
#     11                                               # Compute GDP Growth and Volatility
#     12         2     213000.0 106500.0      0.0      meta = pd.DataFrame({
#     13         1      72000.0  72000.0      0.0          'code':        pd.Series(dtype='object'),
#     14         1      43000.0  43000.0      0.0          'mean_growth': pd.Series(dtype='float64'),
#     15         1      35000.0  35000.0      0.0          'mean_vol':    pd.Series(dtype='float64'),
#     16                                               })
#     17
#     18         2     409000.0 204500.0      0.0      country_summaries = ddf.groupby('code', observed=True).apply(
#     19         1       1000.0   1000.0      0.0          summarize_country,
#     20         1          0.0      0.0      0.0          meta=meta
#     21                                               )
#     22
#     23         1      51000.0  51000.0      0.0      country_summaries = country_summaries.reset_index(drop=True)
#     24
#     25                                               # Aggregate regions
#     26         1      32000.0  32000.0      0.0      country_summaries = country_summaries.astype({'code': 'string'})
#     27         1      26000.0  26000.0      0.0      regions = regions.astype({'code': 'string'})
#     28
#     29         1     212000.0 212000.0      0.0      country_summaries = country_summaries.merge(regions, on='code')
#     30
#     31         1          0.0      0.0      0.0      result = (
#     32         2     423000.0 211500.0      0.0          country_summaries
#     33         1      90000.0  90000.0      0.0          .groupby('region', observed=True)[['mean_growth', 'mean_vol']]
#     34         1    3158000.0    3e+06      0.1          .mean()
#     35         1 2335759000.0    2e+09     97.1          .compute()
#     36                                               )
#     37         1          0.0      0.0      0.0      return result

# %%
import sys
!"{sys.executable}" -m memory_profiler app_v2.py
# Out:
# Filename: app_v2.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     25  156.203 MiB  156.203 MiB           1   @profile
#     26                                         def run_analysis_v2():
#     27                                             # Load data
#     28  162.391 MiB    6.188 MiB           2       ddf = dd.read_parquet(
#     29  156.203 MiB    0.000 MiB           1           'gdp_panel_parquet/',
#     30  156.203 MiB    0.000 MiB           1           columns=['code','year','value'],
#     31  156.203 MiB    0.000 MiB           1           engine='pyarrow'
#     32                                             )
#     33
#     34  163.406 MiB    1.016 MiB           1       regions = dd.read_parquet('country_region_parquet/')
#     35
#     36                                             # Compute GDP Growth and Volatility
#     37  163.406 MiB    0.000 MiB           2       meta = pd.DataFrame({
#     38  163.406 MiB    0.000 MiB           1           'code':        pd.Series(dtype='object'),
#     39  163.406 MiB    0.000 MiB           1           'mean_growth': pd.Series(dtype='float64'),
#     40  163.406 MiB    0.000 MiB           1           'mean_vol':    pd.Series(dtype='float64'),
#     41                                             })
#     42
#     43  163.562 MiB    0.156 MiB           2       country_summaries = ddf.groupby('code', observed=True).apply(
#     44  163.547 MiB    0.000 MiB           1           summarize_country,
#     45  163.547 MiB    0.000 MiB           1           meta=meta
#     46                                             )
#     47
#     48  163.562 MiB    0.000 MiB           1       country_summaries = country_summaries.reset_index(drop=True)
#     49
#     50                                             # Aggregate regions
#     51  163.656 MiB    0.094 MiB           1       country_summaries = country_summaries.astype({'code': 'string'})
#     52  163.656 MiB    0.000 MiB           1       regions = regions.astype({'code': 'string'})
#     53
#     54  164.219 MiB    0.562 MiB           1       country_summaries = country_summaries.merge(regions, on='code')
#     55
#     56  209.328 MiB    0.000 MiB           1       result = (
#     57  164.250 MiB    0.031 MiB           2           country_summaries
#     58  164.219 MiB    0.000 MiB           1           .groupby('region', observed=True)[['mean_growth', 'mean_vol']]
#     59  164.938 MiB    0.688 MiB           1           .mean()
#     60  209.328 MiB   44.391 MiB           1           .compute()
#     61                                             )
#     62  209.328 MiB    0.000 MiB           1       return result

# %% [markdown]
# ## 5. CPU Bound -> Parallel Computing

# %%
import os
import glob
import numpy as np
import pandas as pd
import pyarrow.parquet as pq
from dask.distributed import Client

# %% [markdown]
# ### 5.1 Prepare Parquet Data

# %%
# Read the raw CSV in parallel
ddf = dd.read_csv(
    'gdp_panel.csv',
    usecols=['code','year','value'],
    parse_dates=['year'],
    dtype={'code':'category'}
)
ddf['code'] = ddf['code'].astype(str)

# Write out as partitioned Parquet
#    Here we partition by 'country' so that each country’s data lives in its own sub-folder.
ddf.to_parquet(
    'gdp_panel_parquet/',
    engine='pyarrow',
    write_index=False,         # drop the old CSV index
    partition_on=['code'],  # creates subfolders country=AAA, country=BBB, …
    compression='snappy'       # fast compression
)

# %% [markdown]
# ### 5.2 Functions to Detect and Process Single Files

# %%
def discover_country_tasks(base_dir):
    tasks = []
    for entry in os.listdir(base_dir):
        full = os.path.join(base_dir, entry)
        if not (entry.startswith("code=") and os.path.isdir(full)):
            continue

        code = entry.split("=", 1)[1]
        pattern = os.path.join(full, "*.parquet")
        files = sorted(glob.glob(pattern))
        if files:
            tasks.append((code, files))
    return tasks

# %%
def process_country(code, parquet_paths):
    # parquet_paths: list of all .parquet files for a single country-partition
    # read them all (value only), concatenate into one 1-D numpy array
    arrays = []
    for path in parquet_paths:
        tbl = pq.read_table(path, columns=['value'])
        arrays.append(tbl.column('value').to_numpy())
    series = np.concatenate(arrays)
    # now do the window‐period rolling growth & vol
    window = 365
    growth = (series[window:] - series[:-window]) / series[:-window]
    windows = np.lib.stride_tricks.sliding_window_view(series, window)
    vol    = np.std(windows, axis=1)
    return code, (growth.mean(), vol.mean())

# %% [markdown]
# ### 5.3 Process Files in Parallel

# %%
# Discover tasks
tasks = discover_country_tasks('gdp_panel_parquet/')
tasks[:5]
# Out:
# [('BRN', ['gdp_panel_parquet/code=BRN/part.0.parquet']),
#  ('AGO', ['gdp_panel_parquet/code=AGO/part.0.parquet']),
#  ('GNB', ['gdp_panel_parquet/code=GNB/part.0.parquet']),
#  ('OMN', ['gdp_panel_parquet/code=OMN/part.0.parquet']),
#  ('MNE', ['gdp_panel_parquet/code=MNE/part.0.parquet'])]

# %%
# Launch Dask
client = Client() 
print(client)
# Out:
# <Client: 'tcp://127.0.0.1:50715' processes=5 threads=10, memory=16.00 GiB>

# %%
# Submit tasks
futures = client.map(lambda args: process_country(*args), tasks)
results = client.gather(futures)

# %%
# Close Dask
client.close()

# %%
# Build DataFrame & merge
df = pd.DataFrame(
    [(code, g, v) for code, (g, v) in results],
    columns=['code','avg_growth','avg_vol']
)
regions = pd.read_csv('country_region.csv', dtype={"code": str})
df = df.merge(regions, on="code", how="left")

# %% [markdown]
# ### 5.4 Aggregate Region

# %%
# Aggregate by region
result = df.groupby("region")[["avg_growth", "avg_vol"]].mean()
result
# Out:
#                avg_growth       avg_vol
# region
# Africa           0.183315    190.690864
# Asia             0.238960  11842.794822
# Europe           0.103997    199.848221
# North America    0.129856     41.620780
# Oceania          0.099840      3.470298
# South America    0.127411   1559.345315

# %% [markdown]
# ### 5.5 Time and Memory Profiling

# %%
def run_analysis_v3():
    # Discover tasks
    tasks = discover_country_tasks('gdp_panel_parquet/')

    # Launch Dask
    client = Client() 

    # Submit Tasks
    futures = client.map(lambda args: process_country(*args), tasks)
    results = client.gather(futures)

    # Close Dask
    client.close() 

    # Build DataFrame & merge
    df = pd.DataFrame(
        [(code, g, v) for code, (g, v) in results],
        columns=['code','avg_growth','avg_vol']
    )
    regions = pd.read_csv('country_region.csv', dtype={"code": str})
    df = df.merge(regions, on="code", how="left")

    # Aggregate by region
    result = df.groupby("region")[["avg_growth", "avg_vol"]].mean()

    return result

# %lprun -f run_analysis_v3 run_analysis_v3()
# Out:
# Timer unit: 1e-09 s
#
# Total time: 0.938876 s
# File: /var/folders/j4/72zz472s4sdd1r1ssyml8k5w0000gn/T/ipykernel_30612/188904422.py
# Function: run_analysis_v3 at line 1
#
# Line #      Hits         Time  Per Hit   % Time  Line Contents
# ==============================================================
#      1                                           def run_analysis_v3():
#      2                                               # Discover tasks
#      3         1   25342000.0    3e+07      2.7      tasks = discover_country_tasks('gdp_panel_parquet/')
#      4
#      5                                               # Launch Dask
#      6         1  394891000.0    4e+08     42.1      client = Client()
#      7
#      8                                               # Submit Tasks
#      9         1    7049000.0    7e+06      0.8      futures = client.map(lambda args: process_country(*args), tasks)
#     10         1  389620000.0    4e+08     41.5      results = client.gather(futures)
#     11
#     12                                               # Close Dask
#     13         1  118304000.0    1e+08     12.6      client.close()
#     14
#     15                                               # Build DataFrame & merge
#     16         2     455000.0 227500.0      0.0      df = pd.DataFrame(
#     17       190      31000.0    163.2      0.0          [(code, g, v) for code, (g, v) in results],
#     18         1       4000.0   4000.0      0.0          columns=['code','avg_growth','avg_vol']
#     19                                               )
#     20         1    1561000.0    2e+06      0.2      regions = pd.read_csv('country_region.csv', dtype={"code": str})
#     21         1    1014000.0    1e+06      0.1      df = df.merge(regions, on="code", how="left")
#     22
#     23                                               # Aggregate by region
#     24         1     604000.0 604000.0      0.1      result = df.groupby("region")[["avg_growth", "avg_vol"]].mean()
#     25
#     26         1       1000.0   1000.0      0.0      return result

# %%
import sys
!"{sys.executable}" -m memory_profiler app_v3.py
# Out:
# Filename: app_v3.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     42  139.078 MiB  139.078 MiB           1   @profile
#     43                                         def run_analysis_v3():
#     44                                             # Discover tasks
#     45  139.141 MiB    0.062 MiB           1       tasks = discover_country_tasks('gdp_panel_parquet/')
#     46
#     47                                             # Launch Dask
#     48  143.000 MiB    3.859 MiB           1       client = Client()
#     49
#     50                                             # Submit Tasks
#     51  143.156 MiB    0.156 MiB           1       futures = client.map(lambda args: process_country(*args), tasks)
#     52  145.547 MiB    2.391 MiB           1       results = client.gather(futures)
#     53
#     54                                             # Close Dask
#     55  145.156 MiB   -0.391 MiB           1       client.close()
#     56
#     57                                             # Build DataFrame & merge
#     58  145.344 MiB    0.188 MiB           2       df = pd.DataFrame(
#     59  145.156 MiB    0.000 MiB         190           [(code, g, v) for code, (g, v) in results],
#     60  145.156 MiB    0.000 MiB           1           columns=['code','avg_growth','avg_vol']
#     61                                             )
#     62  145.594 MiB    0.250 MiB           1       regions = pd.read_csv('country_region.csv', dtype={"code": str})
#     63  146.188 MiB    0.594 MiB           1       df = df.merge(regions, on="code", how="left")
#     64
#     65                                             # Aggregate by region
#     66  146.406 MiB    0.219 MiB           1       result = df.groupby("region")[["avg_growth", "avg_vol"]].mean()
#     67
#     68  146.406 MiB    0.000 MiB           1       return result
