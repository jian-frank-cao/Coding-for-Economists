# %% [markdown]
# # Coding for Economists - Session 8

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Setup Environment

# %%
# %pip install networkx torch torch_geometric
# Out:
# Requirement already satisfied: networkx in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (3.4.2)
# Requirement already satisfied: torch in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (2.6.0)
# Collecting torch_geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (3.11.10)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (5.9.0)
# Requirement already satisfied: pyparsing in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (3.2.0)
# Requirement already satisfied: requests in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (2.32.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from torch_geometric) (4.67.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from aiohttp->torch_geometric) (1.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests->torch_geometric) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests->torch_geometric) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests->torch_geometric) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests->torch_geometric) (2025.1.31)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 10.3 MB/s eta 0:00:00
# Installing collected packages: torch_geometric
# Successfully installed torch_geometric-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install econml
# Out:
# Collecting econml
#   Downloading econml-0.15.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (38 kB)
# Requirement already satisfied: numpy<2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (1.26.4)
# Requirement already satisfied: scipy>1.4.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (1.15.1)
# Collecting scikit-learn<1.6,>=1.0 (from econml)
#   Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl.metadata (13 kB)
# Collecting sparse (from econml)
#   Downloading sparse-0.16.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: joblib>=0.13.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (1.4.2)
# Requirement already satisfied: statsmodels>=0.10 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (0.14.4)
# Requirement already satisfied: pandas>1.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (2.2.3)
# Collecting shap<0.44.0,>=0.38.1 (from econml)
#   Downloading shap-0.43.0.tar.gz (389 kB)
#   Installing build dependencies .done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting lightgbm (from econml)
#   Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl.metadata (17 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from econml) (24.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from pandas>1.0->econml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from pandas>1.0->econml) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from pandas>1.0->econml) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from scikit-learn<1.6,>=1.0->econml) (3.5.0)
# Collecting tqdm>=4.27.0 (from shap<0.44.0,>=0.38.1->econml)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting slicer==0.0.7 (from shap<0.44.0,>=0.38.1->econml)
#   Downloading slicer-0.0.7-py3-none-any.whl.metadata (3.7 kB)
# Collecting numba (from shap<0.44.0,>=0.38.1->econml)
#   Downloading numba-0.61.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: cloudpickle in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from shap<0.44.0,>=0.38.1->econml) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from statsmodels>=0.10->econml) (1.0.1)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba->shap<0.44.0,>=0.38.1->econml)
#   Downloading llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>1.0->econml) (1.16.0)
# Downloading econml-0.15.1-cp312-cp312-macosx_11_0_arm64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 14.1 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.2-cp312-cp312-macosx_12_0_arm64.whl (11.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 14.6 MB/s eta 0:00:00 0:00:01
# Downloading slicer-0.0.7-py3-none-any.whl (14 kB)
# Downloading lightgbm-4.6.0-py3-none-macosx_12_0_arm64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.2 MB/s eta 0:00:00
# Downloading sparse-0.16.0-py2.py3-none-any.whl (147 kB)
# Downloading numba-0.61.0-cp312-cp312-macosx_11_0_arm64.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 18.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-macosx_11_0_arm64.whl (26.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/26.2 MB 23.0 MB/s eta 0:00:00a 0:00:01
# Building wheels for collected packages: shap
#   Building wheel for shap (pyproject.tomldone
#   Created wheel for shap: filename=shap-0.43.0-cp312-cp312-macosx_11_0_arm64.whl size=442894 sha256=1ca99dfe2dd9d9c10ea99e199774f9c8c449043399d85612978f1f3b34521f2b
#   Stored in directory: /Users/jiancao/Library/Caches/pip/wheels/e0/cb/3e/46cb0f77e2e4f5aa9fd5d399dedb3ba84f91f0c49e3db7d0e1
# Successfully built shap
# Installing collected packages: tqdm, slicer, llvmlite, scikit-learn, numba, lightgbm, sparse, shap, econml
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# Successfully installed econml-0.15.1 lightgbm-4.6.0 llvmlite-0.44.0 numba-0.61.0 scikit-learn-1.5.2 shap-0.43.0 slicer-0.0.7 sparse-0.16.0 tqdm-4.67.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade jupyter ipywidgets
# Out:
# Collecting jupyter
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.5-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: notebook in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter) (7.3.2)
# Collecting jupyter-console (from jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: nbconvert in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter) (7.16.4)
# Requirement already satisfied: ipykernel in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter) (6.29.5)
# Requirement already satisfied: jupyterlab in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter) (4.3.4)
# Requirement already satisfied: comm>=0.1.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipywidgets) (0.2.1)
# Requirement already satisfied: ipython>=6.1.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipywidgets) (8.30.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.12 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab-widgets~=3.0.12 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: decorator in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: appnope in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (1.8.11)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (5.7.2)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (24.2)
# Requirement already satisfied: psutil in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (26.2.0)
# Requirement already satisfied: tornado>=6.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from ipykernel->jupyter) (6.4.2)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.27.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (3.1.5)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (0.2.3)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab->jupyter) (72.1.0)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (0.1.2)
# Requirement already satisfied: markupsafe>=2.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (4.6.2)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.0.2)
# Requirement already satisfied: idna in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (3.7)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (3.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.21.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.23.0)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.3)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: executing in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (21.2.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.22.3)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel->jupyter) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.3.0)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting jsonpointer>1.13 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/envs/pyenv01/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading ipywidgets-8.1.5-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.13-py3-none-any.whl (214 kB)
# Downloading widgetsnbextension-4.0.13-py3-none-any.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 17.7 MB/s eta 0:00:00
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: widgetsnbextension, webcolors, uri-template, jupyterlab-widgets, jsonpointer, fqdn, isoduration, ipywidgets, jupyter-console, jupyter
# Successfully installed fqdn-1.5.1 ipywidgets-8.1.5 isoduration-20.11.0 jsonpointer-3.0.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyterlab-widgets-3.0.13 uri-template-1.3.0 webcolors-24.11.1 widgetsnbextension-4.0.13
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Turn on copy on write
pd.options.mode.copy_on_write = True

# %% [markdown]
# ## 2. K-Means Clustering

# %% [markdown]
# ### 2.1 Read Data

# %%
# Load the publicly available macroeconomic dataset
import statsmodels.api as sm
data = sm.datasets.macrodata.load_pandas().data

# Select a subset of economic indicators for clustering
# Here we use real GDP, inflation, and unemployment
df = data[['realgdp', 'infl', 'unemp']]
df.head()
# Out:
#     realgdp  infl  unemp
# 0  2710.349  0.00    5.8
# 1  2778.801  2.34    5.1
# 2  2775.488  2.74    5.3
# 3  2785.204  0.27    5.6
# 4  2847.699  2.31    5.2

# %% [markdown]
# ### 2.2 Preprocessing

# %%
# Scale the data (important for clustering)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %% [markdown]
# ### 2.3 Determine the Optimal Number of Clusters

# %%
# Determine the optimal number of clusters using the elbow method
from sklearn.cluster import KMeans
inertia = []
K_range = range(1, 11)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)

# Plot the elbow curve (within cluster sum of squares)
plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
# Determine optimal k using silhouette scores (requires k>=2)
from sklearn.metrics import silhouette_score
silhouette_scores = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(scaled_data)
    score = silhouette_score(scaled_data, labels)
    silhouette_scores.append(score)

# Plot the silhouette scores
plt.figure(figsize=(8, 4))
plt.plot(range(2, 11), silhouette_scores, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Different k')
plt.show()

# %%
# Based on the elbow and silhouette methods, choose an optimal k
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# %% [markdown]
# ### 2.4 Visualize the Clusters

# %%
# Add cluster labels to the dataframe
df['cluster'] = clusters

# Use PCA to reduce dimensions to 2 for visualization purposes
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=1234)
pca_result = pca.fit_transform(scaled_data)
df['pca1'] = pca_result[:, 0]
df['pca2'] = pca_result[:, 1]
df.head()
# Out:
#     realgdp  infl  unemp  cluster      pca1      pca2
# 0  2710.349  0.00    5.8        2  0.099548 -0.108539
# 1  2778.801  2.34    5.1        2  0.380380 -0.737446
# 2  2775.488  2.74    5.3        2  0.513089 -0.642221
# 3  2785.204  0.27    5.6        2  0.087804 -0.251655
# 4  2847.699  2.31    5.2        2  0.385749 -0.665538

# %%
# Plot the clusters in the PCA-reduced space
plt.figure(figsize=(8, 6))
for cluster in range(optimal_k):
    subset = df[df['cluster'] == cluster]
    plt.scatter(subset['pca1'], subset['pca2'], label=f'Cluster {cluster}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title(f'K-Means Clustering (k={optimal_k})')
plt.legend()
plt.show()

# %% [markdown]
# ## 3. Policy Evaluation: Causal Forest

# %% [markdown]
# ### 3.1 Read Data

# %%
df = pd.read_csv('lalonde_data.csv', index_col=0)
print(df.shape)
df.head()
# Out:
# (614, 10)
#       treat  age  educ  black  hispan  married  nodegree  re74  re75  \
# ID
# NSW1      1   37    11      1       0        1         1   0.0   0.0
# NSW2      1   22     9      0       1        0         1   0.0   0.0
# NSW3      1   30    12      1       0        0         0   0.0   0.0
# NSW4      1   27    11      1       0        0         1   0.0   0.0
# NSW5      1   33     8      1       0        0         1   0.0   0.0
#
#             re78
# ID
# NSW1   9930.0460
# NSW2   3595.8940
# NSW3  24909.4500
# NSW4   7506.1460
# NSW5    289.7899

# %% [markdown]
# - __treat__: 1 participated in job training program, 0 otherwise
# - __age__: measured in years;
# - __educ__: measured in years;
# - __black__: indicating race (1 if black, 0 otherwise);
# - __hispan__: indicating race (1 if Hispanic, 0 otherwise);
# - __married__: indicating marital status (1 if married, 0 otherwise);
# - __nodegree__: indicating high school diploma (1 if no degree, 0 otherwise);
# - __re74__: real earnings in 1974;
# - __re75__: real earnings in 1975;
# - __re78__: real earnings in 1978.

# %%
df.describe()
# Out:
#             treat         age        educ       black      hispan     married  \
# count  614.000000  614.000000  614.000000  614.000000  614.000000  614.000000
# mean     0.301303   27.363192   10.268730    0.395765    0.117264    0.415309
# std      0.459198    9.881187    2.628325    0.489413    0.321997    0.493177
# min      0.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   20.000000    9.000000    0.000000    0.000000    0.000000
# 50%      0.000000   25.000000   11.000000    0.000000    0.000000    0.000000
# 75%      1.000000   32.000000   12.000000    1.000000    0.000000    1.000000
# max      1.000000   55.000000   18.000000    1.000000    1.000000    1.000000
#
#          nodegree          re74          re75          re78
# count  614.000000    614.000000    614.000000    614.000000
# mean     0.630293   4557.546569   2184.938207   6792.834483
# std      0.483119   6477.964479   3295.679043   7470.730792
# min      0.000000      0.000000      0.000000      0.000000
# 25%      0.000000      0.000000      0.000000    238.283425
# 50%      1.000000   1042.330000    601.548400   4759.018500
# 75%      1.000000   7888.498250   3248.987500  10893.592500
# max      1.000000  35040.070000  25142.240000  60307.930000

# %% [markdown]
# ### 3.2 Data Cleaning

# %% [markdown]
# #### Impute Missing Values in `re74` and `re75`

# %%
df[['re74', 're75', 're78']] = df[['re74', 're75', 're78']].replace(0, np.nan)
print("Missing values per column:\n", df.isnull().sum())
# Out:
# Missing values per column:
#  treat         0
# age           0
# educ          0
# black         0
# hispan        0
# married       0
# nodegree      0
# re74        243
# re75        245
# re78        143
# dtype: int64

# %%
# from sklearn.impute import KNNImputer
# # Initialize the KNNImputer with k=2 neighbors and uniform weighting
# imputer = KNNImputer(n_neighbors=2, weights="uniform")

# # Fit the imputer on X and transform the data
# df_imputed = df.drop(['treat', 're78'], axis=1)
# df_imputed = imputer.fit_transform(df_imputed)

# # Transform to pd.DataFrame
# df_imputed = pd.DataFrame(df_imputed, columns = df.columns.values[1:-1], index = df.index.values)
# df[['re74', 're75']] = df_imputed[['re74', 're75']]
# df.head()
# Out:
#       treat  age  educ  black  hispan  married  nodegree        re74  \
# ID
# NSW1      1   37    11      1       0        1         1   6222.6320
# NSW2      1   22     9      0       1        0         1   3938.3550
# NSW3      1   30    12      1       0        0         0  10315.1635
# NSW4      1   27    11      1       0        0         1   1604.0430
# NSW5      1   33     8      1       0        0         1  10175.4510
#
#            re75        re78
# ID
# NSW1  5467.6450   9930.0460
# NSW2  4937.8720   3595.8940
# NSW3  3348.1105  24909.4500
# NSW4  1975.1765   7506.1460
# NSW5  9439.4735    289.7899

# %% [markdown]
# #### Remove Missing Values in `re78`

# %%
# df = df[df['re78'] != 0]
# print(df.shape)
# df.describe()
# Out:
# (471, 10)
#             treat         age        educ       black      hispan     married  \
# count  471.000000  471.000000  471.000000  471.000000  471.000000  471.000000
# mean     0.297240   26.704883   10.371550    0.369427    0.127389    0.422505
# std      0.457529    9.167470    2.546578    0.483163    0.333762    0.494483
# min      0.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   19.000000    9.000000    0.000000    0.000000    0.000000
# 50%      0.000000   24.000000   11.000000    0.000000    0.000000    0.000000
# 75%      1.000000   31.000000   12.000000    1.000000    0.000000    1.000000
# max      1.000000   53.000000   18.000000    1.000000    1.000000    1.000000
#
#          nodegree          re74          re75          re78
# count  471.000000    471.000000    471.000000    471.000000
# mean     0.622081   7102.740233   3602.004419   8855.202489
# std      0.485383   6540.823797   3355.531887   7381.823498
# min      0.000000     39.185340     10.741940     31.032260
# 25%      0.000000   1576.230000   1259.598500   3040.647500
# 50%      1.000000   5023.560000   2674.742000   7215.739000
# 75%      1.000000  10863.155000   5044.234000  12909.895000
# max      1.000000  35040.070000  25142.240000  60307.930000

# %%
df = df.dropna()
df.describe()
# Out:
#             treat         age        educ       black      hispan     married  \
# count  245.000000  245.000000  245.000000  245.000000  245.000000  245.000000
# mean     0.159184   27.661224   10.383673    0.236735    0.146939    0.555102
# std      0.366596    9.287503    2.691772    0.425948    0.354770    0.497972
# min      0.000000   16.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   20.000000    9.000000    0.000000    0.000000    0.000000
# 50%      0.000000   25.000000   11.000000    0.000000    0.000000    1.000000
# 75%      0.000000   33.000000   12.000000    0.000000    0.000000    1.000000
# max      1.000000   53.000000   18.000000    1.000000    1.000000    1.000000
#
#          nodegree          re74          re75          re78
# count  245.000000    245.000000    245.000000    245.000000
# mean     0.567347   8302.692724   4285.098276   9347.533904
# std      0.496458   7121.980494   3875.862000   7160.267924
# min      0.000000     39.185340     10.741940     94.574500
# 25%      0.000000   2192.877000   1383.919000   3683.972000
# 50%      1.000000   6759.994000   3328.210000   7539.361000
# 75%      1.000000  12312.030000   6099.629000  14038.400000
# max      1.000000  35040.070000  25142.240000  36646.950000

# %% [markdown]
# ### 3.3 Preprocessing

# %%
df.dtypes
# Out:
# treat         int64
# age           int64
# educ          int64
# black         int64
# hispan        int64
# married       int64
# nodegree      int64
# re74        float64
# re75        float64
# re78        float64
# dtype: object

# %% [markdown]
# ### 3.4 Prepare Train/Test Sets

# %%
# Define outcome (Y), treatment (T), and covariates (X)
Y = df['re78'].values       # outcome variable: earnings in 1978
T = df['treat'].values      # treatment indicator
# Use remaining columns as covariates
X = df.drop(columns=['treat', 're78']).values

# Split into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test, T_train, T_test = train_test_split(
    X, Y, T, test_size=0.2, random_state=1234
)

# %% [markdown]
# ### 3.5 Implement Causal Forest and Tune Parameters

# %% [markdown]
# #### Define Hyperparameter Grid for Tuning
# - __n_estimators__: The number of trees in the forest.
# - __max_depth__: The maximum depth of the tree.
# - __min_samples_split__: The minimum number of samples required to split an internal node.
# - __max_features__: The number of features to consider when looking for the best split.

# %%
param_grid = {
    'n_estimators': [400, 500],
    'max_depth': [3, 5],
    'min_samples_split': [2, 5],
    'max_features': ['sqrt', None]
}

best_model = None
best_params = None
best_cate_std = np.inf

# %% [markdown]
# #### Grid Search

# %%
from sklearn.model_selection import ParameterGrid
from econml.dml import CausalForestDML
# For causal inference, one approach is to choose the hyperparameters that provide stable (low-variance) CATE estimates.
# Here, as a demo, we use the standard deviation of the estimated Conditional Average Treatment Effects (CATE)
# on the test set as a proxy (lower variance can indicate more stable estimates).

for params in ParameterGrid(param_grid):
    model = CausalForestDML(
        model_y='forest',
        model_t='forest',
        n_estimators=params['n_estimators'],
        max_depth=params['max_depth'],
        min_samples_split=params['min_samples_split'],
        max_features=params['max_features'],
        random_state=1234,
        verbose=0
    )
    model.fit(Y_train, T_train, X=X_train)
    # Estimate the CATE on the test set
    cate_test = model.effect(X_test)
    cate_std = np.std(cate_test)
    print(f"Params: {params}, CATE std: {cate_std:.2f}")
    
    if cate_std < best_cate_std:
        best_cate_std = cate_std
        best_params = params
        best_model = model

print("\nBest Hyperparameters:", best_params)
# Out:
# Params: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 400}, CATE std: 987.21
# Params: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 500}, CATE std: 949.39
# Params: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 400}, CATE std: 987.21
# Params: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 500}, CATE std: 949.39
# Params: {'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 400}, CATE std: 1052.85
# Params: {'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 500}, CATE std: 1066.13
# Params: {'max_depth': 3, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 400}, CATE std: 1052.85
# Params: {'max_depth': 3, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 500}, CATE std: 1066.13
# Params: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 400}, CATE std: 1425.68
# Params: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 500}, CATE std: 1377.56
# Params: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 400}, CATE std: 1425.68
# Params: {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 500}, CATE std: 1377.56
# Params: {'max_depth': 5, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 400}, CATE std: 1477.35
# Params: {'max_depth': 5, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 500}, CATE std: 1507.77
# Params: {'max_depth': 5, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 400}, CATE std: 1477.35
# Params: {'max_depth': 5, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 500}, CATE std: 1507.77
#
# Best Hyperparameters: {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 500}

# %% [markdown]
# ### 3.6 Validate the Model

# %%
# Estimate the Average Treatment Effect (ATE) and its confidence interval on the test set.
ate_point = best_model.ate(X_test)
ate_lb, ate_ub = best_model.ate_interval(X_test, alpha=0.05)
print(f"\nEstimated ATE: {ate_point:.2f}")
print(f"95% Confidence Interval for ATE: ({ate_lb:.2f}, {ate_ub:.2f})")

# Also, compute CATE for each test observation
cate_pred = best_model.effect(X_test)
# Out:
# Estimated ATE: 451.52
# 95% Confidence Interval for ATE: (-1932.90, 2835.93)

# %% [markdown]
# ### 3.7 Visualization

# %%
# Plot 1: Histogram of Estimated CATE
plt.figure(figsize=(8, 5))
plt.hist(cate_pred, bins=30, edgecolor='k', alpha=0.7)
plt.title("Distribution of Estimated Conditional Treatment Effects (CATE)")
plt.xlabel("Estimated Treatment Effect")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Plot 2: Scatter Plot of CATE vs. a Covariate (e.g., Age)
# Assuming the first column in X corresponds to age
age_test = X_test[:, 0]
plt.figure(figsize=(8, 5))
plt.scatter(age_test, cate_pred, alpha=0.6, edgecolor='k')
plt.title("Estimated Treatment Effect vs. Age")
plt.xlabel("Age")
plt.ylabel("Estimated Treatment Effect")
plt.grid(True)
plt.show()

# %%
# Plot 3: Visualize the ATE with its Confidence Interval
plt.figure(figsize=(6, 4))
plt.errorbar(1, ate_point, yerr=[[ate_point - ate_lb], [ate_ub - ate_point]], fmt='o', color='red', capsize=5)
plt.xlim(0.5, 1.5)
plt.xticks([1], ['ATE'])
plt.title("Average Treatment Effect with 95% Confidence Interval")
plt.ylabel("Treatment Effect")
plt.grid(True)
plt.show()

# %%
# Use "pip install econml" on the command line to install the package
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from econml.orf import DMLOrthoForest as CausalForest

df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/Ecdat/Crime.csv')

# Set the categorical variables:
cat_vars = ['year', 'region', 'smsa']
# Transform the categorical variables to dummies and add them back in
xf = pd.get_dummies(df[cat_vars])
df = pd.concat([df.drop(cat_vars, axis=1), xf], axis=1)
cat_var_dummy_names = list(xf.columns)

regressors = ['prbarr', 'prbconv', 'prbpris',
              'avgsen', 'polpc', 'density', 'taxpc',
              'pctmin', 'wcon']
# Add in the dummy names to the list of regressors
regressors = regressors + cat_var_dummy_names

# Split into train and test
train, test = train_test_split(df, test_size=0.2)

# Estimate causal forest
estimator = CausalForest(n_trees=100,
                         model_T=DecisionTreeRegressor(),
                         model_Y=DecisionTreeRegressor())
estimator.fit(Y=train['crmrte'],
              T=train['pctymle'],
              W=train[regressors],
              X=train[regressors],
              inference='blb')
effects_train = estimator.effect(train[regressors])
effects_test = estimator.effect(test[regressors])
conf_intrvl = estimator.effect_interval(test[regressors])
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:   23.5s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:   23.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 244 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 316 out of 504 | elapsed:    5.3s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 504 out of 504 | elapsed:    5.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 107 out of 126 | elapsed:    0.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 126 out of 126 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 10 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 126 out of 126 | elapsed:    0.2s finished
