# %% [markdown]
# # Coding for Economists - Session 8

# %% [markdown]
# ***

# %% [markdown]
# ## 1. Setup Environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Turn on copy on write
pd.options.mode.copy_on_write = True

# %% [markdown]
# ## 2. Random Forest

# %% [markdown]
# ### 2.1 Read Data

# %%
# Load public economic data (macrodata dataset)
import statsmodels.api as sm
df = sm.datasets.macrodata.load_pandas().data
print("Initial dataset shape:", df.shape)
df.head()
# Out:
# Initial dataset shape: (203, 14)
#      year  quarter   realgdp  realcons  realinv  realgovt  realdpi    cpi  \
# 0  1959.0      1.0  2710.349    1707.4  286.898   470.045   1886.9  28.98
# 1  1959.0      2.0  2778.801    1733.7  310.859   481.301   1919.7  29.15
# 2  1959.0      3.0  2775.488    1751.8  289.226   491.260   1916.4  29.35
# 3  1959.0      4.0  2785.204    1753.7  299.356   484.052   1931.3  29.37
# 4  1960.0      1.0  2847.699    1770.5  331.722   462.199   1955.5  29.54
#
#       m1  tbilrate  unemp      pop  infl  realint
# 0  139.7      2.82    5.8  177.146  0.00     0.00
# 1  141.7      3.08    5.1  177.830  2.34     0.74
# 2  140.5      3.82    5.3  178.657  2.74     1.09
# 3  140.0      4.33    5.6  179.386  0.27     4.06
# 4  139.6      3.50    5.2  180.007  2.31     1.19

# %%
df.dtypes
# Out:
# year        float64
# quarter     float64
# realgdp     float64
# realcons    float64
# realinv     float64
# realgovt    float64
# realdpi     float64
# cpi         float64
# m1          float64
# tbilrate    float64
# unemp       float64
# pop         float64
# infl        float64
# realint     float64
# dtype: object

# %% [markdown]
# ### 2.2 Preprocessing

# %% [markdown]
# #### Create Labels

# %%
# Create a binary target variable 'high_inflation'
# Label as 1 if inflation is above the median, otherwise 0
median_infl = df['infl'].median()
df['high_inflation'] = (df['infl'] > median_infl).astype(int)
df.drop(['year', 'quarter', 'infl'], axis=1, inplace=True)
print(median_infl)
df.head()
# Out:
# 3.24
#     realgdp  realcons  realinv  realgovt  realdpi    cpi     m1  tbilrate  \
# 0  2710.349    1707.4  286.898   470.045   1886.9  28.98  139.7      2.82
# 1  2778.801    1733.7  310.859   481.301   1919.7  29.15  141.7      3.08
# 2  2775.488    1751.8  289.226   491.260   1916.4  29.35  140.5      3.82
# 3  2785.204    1753.7  299.356   484.052   1931.3  29.37  140.0      4.33
# 4  2847.699    1770.5  331.722   462.199   1955.5  29.54  139.6      3.50
#
#    unemp      pop  realint  high_inflation
# 0    5.8  177.146     0.00               0
# 1    5.1  177.830     0.74               0
# 2    5.3  178.657     1.09               0
# 3    5.6  179.386     4.06               0
# 4    5.2  180.007     1.19               0

# %% [markdown]
# #### Scale the Numeric Features

# %%
# We'll scale the numeric features for better model performance.
# First, identify numeric columns (excluding the target column 'high_inflation')
numeric_features = list(df)
numeric_features.remove('high_inflation')

# Initialize the StandardScaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df[numeric_features] = scaler.fit_transform(df[numeric_features])
df.head()
# Out:
#     realgdp  realcons   realinv  realgovt   realdpi       cpi        m1  \
# 0 -1.406543 -1.351117 -1.243818 -1.375525 -1.416168 -1.244865 -1.162925
# 1 -1.385199 -1.339720 -1.202765 -1.295420 -1.402600 -1.242084 -1.158521
# 2 -1.386232 -1.331876 -1.239829 -1.224546 -1.403965 -1.238812 -1.161163
# 3 -1.383202 -1.331053 -1.222473 -1.275843 -1.397802 -1.238485 -1.162264
# 4 -1.363715 -1.323773 -1.167020 -1.431362 -1.387792 -1.235704 -1.163145
#
#    tbilrate     unemp       pop   realint  high_inflation
# 0 -0.891142 -0.058234 -1.677778 -0.502026               0
# 1 -0.798157 -0.539341 -1.659439 -0.224062               0
# 2 -0.533508 -0.401882 -1.637266 -0.092593               0
# 3 -0.351115 -0.195693 -1.617721  1.023019               0
# 4 -0.647951 -0.470612 -1.601072 -0.055030               0

# %% [markdown]
# ### 2.3 Prepare Train/Test Sets

# %% [markdown]
# #### Train/Test Split
# - __realgdp__: Real GDP
# - __realcons__: Real Consumption
# - __realinv__: Real Investment
# - __realgovt__: Real Government Spending
# - __realdpi__: Disposable Personal Income
# - __m1__: Money Supply
# - __unemp__: Unemployment
# - __pop__: Population

# %%
# Define features and target for classification
features = ['realgdp', 'realcons', 'realinv', 'realgovt', 'realdpi', 'm1', 'unemp', 'pop']
target = 'high_inflation'

X = df[features]
y = df[target]

# %%
# Split into training and testing sets (80/20 split)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=1234, stratify=y # stratify=y ensures distribution of y is preserved in both training and testing sets
)
print("Training set shape:", X_train.shape)
print("Test set shape:", X_test.shape)
# Out:
# Training set shape: (162, 8)
# Test set shape: (41, 8)

# %% [markdown]
# #### Check if training set is balanced

# %%
print(y_train.value_counts())
# Out:
# high_inflation
# 1    81
# 0    81
# Name: count, dtype: int64

# %% [markdown]
# ### 2.4 Tune the Random Forest Classifier

# %% [markdown]
# #### Initialize Random Forest Classifier

# %%
# Define the Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier(random_state=1234)

# %% [markdown]
# #### Define Hyperparameter Grid for Tuning
# - __n_estimators__: The number of trees in the forest.
# - __max_depth__: The maximum depth of the tree.
# - __min_samples_split__: The minimum number of samples required to split an internal node.
# - __max_features__: The number of features to consider when looking for the best split.

# %%
# Define the hyperparametere Grid
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [3, 5, 10, None],
    'min_samples_split': [2, 5, 10],
    'max_features': ['sqrt', 'log2', None]
}

# %% [markdown]
# #### Grid Search

# %%
# Use GridSearchCV to tune the Random Forest Classifier
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator=rf_clf, param_grid=param_grid, cv=5, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1234),
#              n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 10, None],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 200]},
#              scoring='accuracy')

# %%
# Convert the grid search results into a DataFrame
results_df = pd.DataFrame(grid_search.cv_results_)
pd.set_option('display.max_colwidth', None)
print(results_df[['params', 'mean_test_score']].to_string())
# Out:
#                                                                                         params  mean_test_score
# 0         {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 50}         0.741477
# 1        {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}         0.747727
# 2        {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}         0.741477
# 3         {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 50}         0.747538
# 4        {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}         0.747727
# 5        {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}         0.741477
# 6        {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 50}         0.747538
# 7       {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}         0.747727
# 8       {'max_depth': 3, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}         0.747727
# 9         {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 50}         0.747727
# 10       {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100}         0.747727
# 11       {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}         0.741667
# 12        {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 50}         0.747727
# 13       {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 100}         0.747727
# 14       {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 200}         0.741667
# 15       {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 50}         0.747727
# 16      {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100}         0.753788
# 17      {'max_depth': 3, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 200}         0.747727
# 18          {'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 50}         0.765909
# 19         {'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 100}         0.759848
# 20         {'max_depth': 3, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 200}         0.747727
# 21          {'max_depth': 3, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 50}         0.765909
# 22         {'max_depth': 3, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 100}         0.759848
# 23         {'max_depth': 3, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 200}         0.747727
# 24         {'max_depth': 3, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 50}         0.765909
# 25        {'max_depth': 3, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 100}         0.759848
# 26        {'max_depth': 3, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 200}         0.747727
# 27        {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 50}         0.759470
# 28       {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}         0.771970
# 29       {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}         0.759659
# 30        {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 50}         0.771780
# 31       {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}         0.771780
# 32       {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}         0.771780
# 33       {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 50}         0.778030
# 34      {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}         0.759470
# 35      {'max_depth': 5, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}         0.759470
# 36        {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 50}         0.759280
# 37       {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100}         0.777841
# 38       {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}         0.759280
# 39        {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 50}         0.765530
# 40       {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 100}         0.784091
# 41       {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 200}         0.765530
# 42       {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 50}         0.765909
# 43      {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100}         0.772159
# 44      {'max_depth': 5, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 200}         0.759659
# 45          {'max_depth': 5, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 50}         0.784280
# 46         {'max_depth': 5, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 100}         0.771970
# 47         {'max_depth': 5, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 200}         0.778220
# 48          {'max_depth': 5, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 50}         0.784280
# 49         {'max_depth': 5, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 100}         0.771970
# 50         {'max_depth': 5, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 200}         0.784470
# 51         {'max_depth': 5, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 50}         0.778220
# 52        {'max_depth': 5, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 100}         0.772159
# 53        {'max_depth': 5, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 200}         0.765909
# 54       {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 50}         0.772348
# 55      {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}         0.766098
# 56      {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}         0.759848
# 57       {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 50}         0.747348
# 58      {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}         0.765909
# 59      {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}         0.765909
# 60      {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 50}         0.771970
# 61     {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}         0.765720
# 62     {'max_depth': 10, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}         0.765720
# 63       {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 50}         0.772348
# 64      {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100}         0.772348
# 65      {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}         0.766098
# 66       {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 50}         0.759659
# 67      {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 100}         0.772159
# 68      {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 200}         0.772159
# 69      {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 50}         0.765909
# 70     {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100}         0.765909
# 71     {'max_depth': 10, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 200}         0.759659
# 72         {'max_depth': 10, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 50}         0.753409
# 73        {'max_depth': 10, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 100}         0.771970
# 74        {'max_depth': 10, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 200}         0.784470
# 75         {'max_depth': 10, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 50}         0.771780
# 76        {'max_depth': 10, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 100}         0.778220
# 77        {'max_depth': 10, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 200}         0.790530
# 78        {'max_depth': 10, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 50}         0.759659
# 79       {'max_depth': 10, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 100}         0.772159
# 80       {'max_depth': 10, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 200}         0.772159
# 81     {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 50}         0.766098
# 82    {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 100}         0.766098
# 83    {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 2, 'n_estimators': 200}         0.759848
# 84     {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 50}         0.747348
# 85    {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 100}         0.765909
# 86    {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 5, 'n_estimators': 200}         0.765909
# 87    {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 50}         0.771970
# 88   {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 100}         0.765720
# 89   {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}         0.765720
# 90     {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 50}         0.772348
# 91    {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 100}         0.766098
# 92    {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 200}         0.766098
# 93     {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 50}         0.759659
# 94    {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 100}         0.772159
# 95    {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 5, 'n_estimators': 200}         0.772159
# 96    {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 50}         0.759848
# 97   {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 100}         0.765909
# 98   {'max_depth': None, 'max_features': 'log2', 'min_samples_split': 10, 'n_estimators': 200}         0.759659
# 99       {'max_depth': None, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 50}         0.753409
# 100     {'max_depth': None, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 100}         0.771970
# 101     {'max_depth': None, 'max_features': None, 'min_samples_split': 2, 'n_estimators': 200}         0.784470
# 102      {'max_depth': None, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 50}         0.771780
# 103     {'max_depth': None, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 100}         0.778220
# 104     {'max_depth': None, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 200}         0.790530
# 105     {'max_depth': None, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 50}         0.759659
# 106    {'max_depth': None, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 100}         0.772159
# 107    {'max_depth': None, 'max_features': None, 'min_samples_split': 10, 'n_estimators': 200}         0.772159

# %%
# Retrieve the best estimator
best_rf_clf = grid_search.best_estimator_
print("Best Parameters:", grid_search.best_params_)
# Out:
# Best Parameters: {'max_depth': 10, 'max_features': None, 'min_samples_split': 5, 'n_estimators': 200}

# %% [markdown]
# ### 2.5 Validate using Testing Set

# %%
# Make predictions on the test set
y_pred = best_rf_clf.predict(X_test)

# Evaluate the classifier using Accuracy and Classification Report
from sklearn.metrics import accuracy_score, classification_report
acc = accuracy_score(y_test, y_pred)
print("Accuracy Score:", acc)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy Score: 0.7317073170731707
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72        21
#            1       0.70      0.80      0.74        20
#
#     accuracy                           0.73        41
#    macro avg       0.74      0.73      0.73        41
# weighted avg       0.74      0.73      0.73        41

# %% [markdown]
# - __Accuracy__: The proportion of all predictions that the model got right.
#
# - __Precision__: The proportion of positive predictions that were actually correct.
#
# - __Recall__: The proportion of actual positives that the model correctly identified.
#
# - __F1-score__: The harmonic mean of precision and recall, providing a balanced measure of both.

# %% [markdown]
# ### 2.6 Plot Important Features

# %%
# Plot the most important features
importances = best_rf_clf.feature_importances_
indices = np.argsort(importances)

plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.barh(range(len(indices)), importances[indices], align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel("Relative Importance")
plt.show()

# %% [markdown]
# ## 3. K-Means

# %% [markdown]
# ### 3.1 Read Data

# %%
# Load the publicly available macroeconomic dataset
import statsmodels.api as sm
data = sm.datasets.macrodata.load_pandas().data

# Select a subset of economic indicators for clustering
# Here we use real GDP, inflation, and unemployment
df = data[['realgdp', 'infl', 'unemp']]
df.head()

# %% [markdown]
# ### 3.2 Preprocessing

# %%
# Scale the data (important for clustering)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %% [markdown]
# ### 3.3 Determine the Optimal Number of Clusters

# %%
# Determine the optimal number of clusters using the elbow method
from sklearn.cluster import KMeans
inertia = []
K_range = range(1, 11)
for k in K_range:
    kmeans = KMeans(n_clusters=k, random_state=1234)
    kmeans.fit(scaled_data)
    inertia.append(kmeans.inertia_)

# Plot the elbow curve (within cluster sum of squares)
plt.figure(figsize=(8, 4))
plt.plot(K_range, inertia, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
# Determine optimal k using silhouette scores (requires k>=2)
from sklearn.metrics import silhouette_score
silhouette_scores = []
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(scaled_data)
    score = silhouette_score(scaled_data, labels)
    silhouette_scores.append(score)

# Plot the silhouette scores
plt.figure(figsize=(8, 4))
plt.plot(range(2, 11), silhouette_scores, 'bo-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Scores for Different k')
plt.show()

# %%
# Based on the elbow and silhouette methods, choose an optimal k
optimal_k = 4
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
clusters = kmeans.fit_predict(scaled_data)

# %% [markdown]
# ### 3.4 Visualize the Clusters

# %%
# Add cluster labels to the dataframe
df['cluster'] = clusters

# Use PCA to reduce dimensions to 2 for visualization purposes
from sklearn.decomposition import PCA
pca = PCA(n_components=2, random_state=1234)
pca_result = pca.fit_transform(scaled_data)
df['pca1'] = pca_result[:, 0]
df['pca2'] = pca_result[:, 1]
df.head()

# %%
# Plot the clusters in the PCA-reduced space
plt.figure(figsize=(8, 6))
for cluster in range(optimal_k):
    subset = df[df['cluster'] == cluster]
    plt.scatter(subset['pca1'], subset['pca2'], label=f'Cluster {cluster}')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title(f'K-Means Clustering (k={optimal_k})')
plt.legend()
plt.show()
